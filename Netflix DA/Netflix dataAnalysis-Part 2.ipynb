# %%
import pandas as pd

# %%
df1=pd.read_csv(r"D:\DA Project\Netflix.csv")

# %%
df1
# Out:
#      Show_Id Category       Title           Director  \
# 0         s2    Movie       07:19  Jorge Michel Grau
# 1         s3    Movie       23:59       Gilbert Chan
# 2         s4    Movie           9        Shane Acker
# 3         s5    Movie          21     Robert Luketic
# 4         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 4806   s7779    Movie  Zombieland    Ruben Fleischer
# 4807   s7781    Movie         Zoo       Shlok Sharma
# 4808   s7782    Movie        Zoom       Peter Hewitt
# 4809   s7783    Movie        Zozo        Josef Fares
# 4810   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 0     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 1     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 2     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 3     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %% [markdown]
# # 8) In how many movies/shows, Tom Cruise was cast ?

# %%
df1.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df1[df1['Cast'] == "Tom Cruise"]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
df1[df1['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df1[df1['Cast'].str.contains('Tom Cruise')]
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\frame.py:3797, in DataFrame.__getitem__(self, key)
#    3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
# -> 3797 if com.is_bool_indexer(key):
#    3798     return self._getitem_bool_array(key)
#    3800 # We are left with two options: a single key, and a collection of keys,
#    3801 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     132     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
# ...

# %%
# we have an error here since it has NA and NaN values, we rectify it by the below new method

# %%
df2 = df1.dropna()

# %%
df2[df2['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 2413   s3861    Movie  Magnolia  Paul Thomas Anderson
# 3153   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 2413  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 3153  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 2413  January 1, 2020      R  189 min  Dramas, Independent Movies
# 3153     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 2413  Through chance, human action, past history and...
# 3153  A fast-talking yuppie is forced to slow down w...

# %% [markdown]
# # 9) What are the different Ratings defined by Netflix ?

# %%
df2['Rating'].nunique()
# Out:
# 14

# %%
df2['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
df2[(df2['Rating'] == "TV-14") & (df2['Category'] == 'Movie') & (df2['Country'] == 'Canada')].shape
# Out:
# (9, 11)

# %% [markdown]
# # 9.2) How many TV Shows Released after year 2018

# %%
df2 = df2.assign(New_Date=pd.to_datetime(df2['Release_Date']))

# %%
df2
# Out:
#      Show_Id Category       Title           Director  \
# 0         s2    Movie       07:19  Jorge Michel Grau
# 1         s3    Movie       23:59       Gilbert Chan
# 2         s4    Movie           9        Shane Acker
# 3         s5    Movie          21     Robert Luketic
# 4         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 4806   s7779    Movie  Zombieland    Ruben Fleischer
# 4807   s7781    Movie         Zoo       Shlok Sharma
# 4808   s7782    Movie        Zoom       Peter Hewitt
# 4809   s7783    Movie        Zozo        Josef Fares
# 4810   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 0     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 1     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 2     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 3     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
df2['Year'] = df2['New_Date'].dt.year

# %%
df2[(df2['Category']=='TV Show') & (df2['Year']> 2018)].shape
# Out:
# (83, 13)

# %%
df2['Category'].value_counts()
# Out:
# Movie      4675
# TV Show     136
# Name: Category, dtype: int64

# %% [markdown]
# # 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
df1.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df1[['Minutes','Units']] = df1['Duration'].str.split(' ', expand = True )

# %%
df1['Minutes'].max()
# Out:
# '99'

# %%
df1
# Out:
#      Show_Id Category       Title           Director  \
# 0         s2    Movie       07:19  Jorge Michel Grau
# 1         s3    Movie       23:59       Gilbert Chan
# 2         s4    Movie           9        Shane Acker
# 3         s5    Movie          21     Robert Luketic
# 4         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 4806   s7779    Movie  Zombieland    Ruben Fleischer
# 4807   s7781    Movie         Zoo       Shlok Sharma
# 4808   s7782    Movie        Zoom       Peter Hewitt
# 4809   s7783    Movie        Zozo        Josef Fares
# 4810   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 0     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 1     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 2     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 3     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %% [markdown]
# # 11) Which individual country has the Highest No. of TV Shows ?

# %%
df1.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description', 'Minutes',
#        'Units'],
#       dtype='object')

# %%
df1_TVShow = df1[df1["Category"] == "TV Show"]

# %%
df1_TVShow['Country'].value_counts().head(1)
# Out:
# United States    27
# Name: Country, dtype: int64

# %% [markdown]
# # 12) How can we sort the dataset by Year ?

# %%
df2.sort_values(by='Year', ascending=False).head(7)
# Out:
#      Show_Id Category                        Title  \
# 1108   s1740    Movie  Dhobi Ghat (Mumbai Diaries)
# 1076   s1691    Movie                  Delhi Belly
# 1518   s2414    Movie                Gimme Shelter
# 3915   s6289    Movie                 The Departed
# 4687   s7570    Movie  What Would Sophia Loren Do?
# 4688   s7571    Movie  What's Eating Gilbert Grape
# 3146   s5060    Movie                 Radium Girls
#
#                               Director  \
# 1108                         Kiran Rao
# 1076                       Abhinay Deo
# 1518                        Ron Krauss
# 3915                   Martin Scorsese
# 4687                     Ross Kauffman
# 4688                   Lasse Hallström
# 3146  Lydia Dean Pilcher, Ginny Mohler
#
#                                                    Cast  \
# 1108  Aamir Khan, Monica Dogra, Kriti Malhotra, Prat...
# 1076  Imran Khan, Vir Das, Kunaal Roy Kapur, Poorna ...
# 1518  Vanessa Hudgens, James Earl Jones, Rosario Daw...
# ...

# %% [markdown]
# # 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
df1[(df1['Category'] == "Movie") & (df1['Type'] == "Dramas") | (df1['Category'] == "TV Show") & (df1['Type'] == "Kids' TV")].head(114)
# Out:
#      Show_Id Category                       Title                Director  \
# 3         s5    Movie                          21          Robert Luketic
# 6         s8    Movie                         187          Kevin Reynolds
# 122     s171    Movie                A Family Man           Mark Williams
# 163     s233    Movie  A Stoning in Fulham County           Larry Elikann
# 197     s277  TV Show                Abby Hatcher             Kyran Kelly
# ...      ...      ...                         ...                     ...
# 4501   s7245    Movie            True to the Game  Preston A. Whitmore II
# 4565   s7363    Movie            Unspeakable Acts              Linda Otto
# 4595   s7413    Movie             Viceroy's House         Gurinder Chadha
# 4597   s7416    Movie                      Victor       Brandon Dickerson
# 4600   s7421    Movie                     Villain        Philip Barantini
#
#                                                    Cast  \
# ...
